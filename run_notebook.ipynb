# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import homography

# %% [markdown]
# ### Load images in and subset to images of specific dimension (honeycomb example)

# %%
honeycomb_img = np.float32(cv2.imread('dtd_folder\dtd\images\honeycombed\honeycombed_0003.jpg')) / 255.0
honeycomb_img = cv2.cvtColor(honeycomb_img, cv2.COLOR_BGR2RGB)
print(honeycomb_img.shape[:2])
plt.imshow(honeycomb_img)
plt.axis('off')
plt.title('Honeycomb Sample Image')
plt.show()
# Out:
# (640, 427)

# %% [markdown]
# ### Apply homography to warp normal input images

# %%
H = homography.generate_homography_warp(honeycomb_img.shape[:2])
warped_img = homography.apply_homography(honeycomb_img, H)

# %%
plt.imshow(warped_img)
plt.axis('off')
plt.title('Warped Honeycomb Sample Image')
plt.show()

# %% [markdown]
# ### Apply homography to unwarp warped input images

# %%
Hp = homography.generate_homography_unwarp(warped_img)
unwarped_img = homography.apply_homography(warped_img, Hp)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Hp = homography.generate_homography_unwarp(warped_img)
#       2 unwarped_img = homography.apply_homography(warped_img, Hp)
#
# File c:\Users\ASC_Student\Documents\GitHub\GAN-Texture-Synthesis\homography.py:77, in generate_homography_unwarp(img)
#      74 plt.imshow(corner_marked_img)
#      76 # Compute the homography matrix
# ---> 77 H, _ = cv2.findHomography(corners_old, corners_new)
#      78 return H
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
